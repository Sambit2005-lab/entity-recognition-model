# %%
# !pip install spacy
# !python -m spacy download en_core_web_sm


import spacy
from spacy.training.example import Example
import random


nlp = spacy.load("en_core_web_sm")


train_data = [
     ("Product X is on sale for $100 with free shipping.", {"entities": [(0, 9, "PRODUCT_NAME"), (32, 36, "PRICE"), (45, 57, "PROMOTION"), (61, 74, "SHIPPING_INFO")]}),
    ("The Samsung Galaxy S21 features a stunning AMOLED display.", {"entities": [(4, 26, "PRODUCT")]}),
    ("Limited stock! Buy now and get a 20% discount on all electronics.", {"entities": [(34, 39, "DISCOUNT"), (43, 52, "CATEGORY")]}),
    ("Our office is located at 123 Main Street, Cityville, USA.", {"entities": [(28, 42, "ADDRESS"), (44, 51, "LOCATION")]}),
    ("XYZ Corporation is offering a special promotion for the holidays.", {"entities": [(0, 15, "ORG"), (44, 62, "PROMOTION"), (68, 75, "EVENT")]}),
    ("Introducing the XYZ SmartWatch with a sleek design and advanced health tracking features.", {"entities": [(16, 30, "PRODUCT_NAME"), (76, 80, "FEATURE")]}),
    ("Get the latest model of the ABC Blender at a discounted price of $149.99.", {"entities": [(32, 43, "PRODUCT_NAME"), (67, 74, "PRICE")]}),
    ("Our furniture sale includes a range of sofa sizes: small, medium, and large.", {"entities": [(23, 33, "CATEGORY"), (49, 54, "SIZE"), (56, 62, "SIZE"), (67, 73, "SIZE")]}),
    ("Limited stock! Buy any laptop and receive a free XYZ Wireless Mouse.", {"entities": [(29, 35, "PRODUCT_TYPE"), (59, 78, "FREE_GIFT")]}),
    ("Explore our outdoor gear collection, featuring backpacks, tents, and sleeping bags.", {"entities": [(27, 38, "CATEGORY"), (47, 55, "PRODUCT"), (58, 63, "PRODUCT"), (68, 80, "PRODUCT")]}),
    ("Hurry! Only a few units left of the XYZ Fitness Tracker in stock.", {"entities": [(44, 46, "AVAILABILITY"), (50, 56, "PRODUCT_NAME")]}),
    ("Check out our clearance sale on shoes. Limited sizes available.", {"entities": [(20, 30, "CATEGORY"), (54, 63, "AVAILABILITY"), (39, 44, "PRODUCT_TYPE")]}),
    ("The new ABC Smartphone is available for pre-order. Reserve yours now!", {"entities": [(14, 29, "PRODUCT_NAME"), (42, 51, "AVAILABILITY")]}),
    ("XYZ Smart TV is back in stock. Order now before it sells out again!", {"entities": [(0, 13, "PRODUCT_NAME"), (29, 34, "AVAILABILITY")]}),
    ("Get detailed specifications for the ABC Digital Camera on our website.", {"entities": [(37, 56, "PRODUCT_NAME"), (3, 23, "TECH_SPEC")]}),
    ("The XYZ Gaming Laptop features a powerful processor and high-resolution display.", {"entities": [(4, 19, "PRODUCT_NAME"), (40, 52, "TECH_SPEC"), (57, 76, "TECH_SPEC")]}),
    ("XYZ Blender, now with a 5-year warranty!", {"entities": [(0, 11, "PRODUCT_NAME"), (31, 44, "WARRANTY_DURATION")]}),
    ("The ABC Smart Home System is compatible with Amazon Alexa and Google Home.", {"entities": [(4, 25, "PRODUCT_NAME"), (45, 58, "COMPATIBILITY"), (63, 75, "COMPATIBILITY")]}),
    ("Visit our store for the latest collection of ABC Watches, available in silver and gold.", {"entities": [(47, 58, "PRODUCT_NAME"), (76, 82, "COLOR"), (87, 91, "COLOR")]}),
    ("Free shipping on orders over $50! Shop now and enjoy the XYZ Bluetooth Earbuds.", {"entities": [(75, 93, "PRODUCT_NAME"), (29, 45, "PROMOTION"), (12, 23, "PRICE")]}),
    ("The ABC Home Decor Collection features a variety of styles for every taste.", {"entities": [(4, 28, "PRODUCT_NAME"), (56, 62, "CATEGORY")]}),
    ("Join our loyalty program and earn points on every purchase of XYZ Fitness Equipment.", {"entities": [(57, 70, "PRODUCT_NAME"), (45, 55, "LOYALTY_PROGRAM")]}),
     ("The XYZ Camera, known for its low-light performance, is now on sale for $499.", {"entities": [(4, 16, "PRODUCT_NAME"), (34, 52, "SPECIAL_FEATURE"), (68, 72, "PRICE")]}),
    ("Shop the ABC Spring Collection for fashionable dresses, now available at discounted prices.", {"entities": [(10, 29, "PRODUCT_NAME"), (65, 75, "SEASON"), (83, 97, "DISCOUNT")]}),
    ("XYZ Laptop: Slim design, powerful performance, and available in silver and space gray.", {"entities": [(0, 9, "PRODUCT_NAME"), (18, 30, "PRODUCT_FEATURE"), (32, 53, "PRODUCT_FEATURE"), (62, 68, "COLOR"), (73, 84, "COLOR")]}),
    ("Limited-time offer! Buy the ABC Soundbar and get a free XYZ Wireless Subwoofer.", {"entities": [(29, 41, "PRODUCT_NAME"), (58, 65, "FREE_GIFT"), (12, 27, "PROMOTION")]}),
    ("The XYZ Bookshelf Speakers deliver immersive sound quality for your home entertainment.", {"entities": [(4, 26, "PRODUCT_NAME"), (47, 64, "PRODUCT_FEATURE")]}),
    ("ABC Kitchen Appliances: Explore our range of high-performance blenders, coffee makers, and more.", {"entities": [(0, 25, "PRODUCT_NAME"), (64, 71, "CATEGORY"), (73, 86, "CATEGORY")]}),
     ("XYZ Wireless Headphones: Immerse yourself in superior audio quality with active noise cancellation.", {"entities": [(0, 22, "PRODUCT_NAME"), (72, 96, "PRODUCT_FEATURE")]}),
    ("Upgrade your home office with the ABC Ergonomic Chair, designed for maximum comfort and lumbar support.", {"entities": [(32, 51, "PRODUCT_NAME"), (71, 93, "PRODUCT_FEATURE"), (98, 112, "PRODUCT_FEATURE")]}),
    ("Introducing the XYZ Smart Thermostat - control your home's temperature with ease using a mobile app.", {"entities": [(16, 36, "PRODUCT_NAME"), (66, 92, "PRODUCT_FEATURE")]}),
    ("The ABC All-in-One Printer offers printing, scanning, and copying capabilities in a compact design.", {"entities": [(4, 26, "PRODUCT_NAME"), (63, 72, "PRODUCT_FEATURE"), (77, 87, "PRODUCT_FEATURE")]}),
    ("XYZ Outdoor Adventure Backpack: Durable, water-resistant, and equipped with multiple compartments.", {"entities": [(0, 27, "PRODUCT_NAME"), (29, 36, "PRODUCT_FEATURE"), (38, 51, "PRODUCT_FEATURE"), (56, 78, "PRODUCT_FEATURE")]}),
    ("Discover the ABC Organic Skincare Collection: Free from harmful chemicals, cruelty-free, and eco-friendly.", {"entities": [(13, 42, "PRODUCT_NAME"), (56, 82, "PRODUCT_FEATURE"), (88, 100, "PRODUCT_FEATURE"), (106, 117, "PRODUCT_FEATURE")]}),
    ("ABC Digital Watch: Waterproof design, customizable watch faces, and GPS tracking.", {"entities": [(0, 15, "PRODUCT_NAME"), (17, 34, "PRODUCT_FEATURE"), (36, 61, "PRODUCT_FEATURE"), (66, 79, "PRODUCT_FEATURE")]}),
    ("XYZ Fitness Apparel: Stay comfortable during workouts with moisture-wicking fabric and breathable materials.", {"entities": [(0, 20, "PRODUCT_NAME"), (50, 72, "PRODUCT_FEATURE"), (77, 96, "PRODUCT_FEATURE")]}),
    ("The ABC Home Security System includes smart cameras, motion detectors, and a central hub for seamless protection.", {"entities": [(4, 27, "PRODUCT_NAME"), (35, 48, "PRODUCT_FEATURE"), (54, 70, "PRODUCT_FEATURE"), (75, 87, "PRODUCT_FEATURE")]}),
    ("Explore our collection of XYZ Gourmet Cooking Utensils: durable, heat-resistant, and stylish.", {"entities": [(29, 42, "PRODUCT_NAME"), (44, 57, "PRODUCT_FEATURE"), (62, 74, "PRODUCT_FEATURE"), (79, 86, "PRODUCT_FEATURE")]}),
    ("Introducing the ABC Solar-Powered Charger: Charge your devices on the go using renewable energy.", {"entities": [(16, 41, "PRODUCT_NAME"), (65, 85, "PRODUCT_FEATURE")]}),
    ("XYZ Virtual Reality Headset: Immerse yourself in a virtual world with high-resolution displays and 360-degree tracking.", {"entities": [(0, 25, "PRODUCT_NAME"), (67, 89, "PRODUCT_FEATURE"), (94, 108, "PRODUCT_FEATURE")]}),
     ("XYZ Wireless Earbuds: Enjoy crystal-clear sound and seamless Bluetooth connectivity.", {"entities": [(0, 22, "PRODUCT_NAME"), (43, 68, "PRODUCT_FEATURE"), (73, 99, "PRODUCT_FEATURE")]}),
    ("The ABC Electric Scooter: Foldable, lightweight, and perfect for urban commuting.", {"entities": [(4, 24, "PRODUCT_NAME"), (26, 35, "PRODUCT_FEATURE"), (37, 48, "PRODUCT_FEATURE"), (53, 72, "PRODUCT_FEATURE")]}),
    ("Introducing the XYZ Smart Refrigerator: Energy-efficient, spacious, and equipped with a touchscreen display.", {"entities": [(16, 38, "PRODUCT_NAME"), (40, 55, "PRODUCT_FEATURE"), (60, 69, "PRODUCT_FEATURE"), (74, 94, "PRODUCT_FEATURE")]}),
    ("Upgrade your gaming setup with the ABC Mechanical Keyboard: RGB backlighting and customizable key switches.", {"entities": [(35, 58, "PRODUCT_NAME"), (60, 72, "PRODUCT_FEATURE"), (77, 104, "PRODUCT_FEATURE")]}),
    ("XYZ Solar Panels: Harness the power of the sun for clean and sustainable energy.", {"entities": [(0, 14, "PRODUCT_NAME"), (62, 88, "PRODUCT_FEATURE")]}),
    ("Discover the ABC Home Gym Set: Includes dumbbells, resistance bands, and a workout mat.", {"entities": [(18, 35, "PRODUCT_NAME"), (42, 51, "PRODUCT_FEATURE"), (57, 72, "PRODUCT_FEATURE"), (77, 88, "PRODUCT_FEATURE")]}),
    ("XYZ Ultra HD Smart TV: 65-inch display, 4K resolution, and built-in streaming apps.", {"entities": [(0, 25, "PRODUCT_NAME"), (27, 40, "PRODUCT_FEATURE"), (42, 54, "PRODUCT_FEATURE"), (59, 83, "PRODUCT_FEATURE")]}),
    ("The ABC DSLR Camera Kit: 24MP sensor, 4K video recording, and included lens accessories.", {"entities": [(4, 22, "PRODUCT_NAME"), (26, 34, "PRODUCT_FEATURE"), (36, 56, "PRODUCT_FEATURE"), (61, 83, "PRODUCT_FEATURE")]}),
    ("XYZ Home Office Desk: Spacious work surface, ergonomic design, and cable management system.", {"entities": [(0, 20, "PRODUCT_NAME"), (22, 38, "PRODUCT_FEATURE"), (40, 56, "PRODUCT_FEATURE"), (61, 86, "PRODUCT_FEATURE")]}),
    ("Upgrade your audio experience with the ABC Surround Sound System: 5.1 channels and wireless subwoofer.", {"entities": [(39, 64, "PRODUCT_NAME"), (66, 77, "PRODUCT_FEATURE"), (82, 104, "PRODUCT_FEATURE")]}),
    ("XYZ Fitness Tracker: Heart rate monitoring, sleep tracking, and waterproof design.", {"entities": [(0, 20, "PRODUCT_NAME"), (22, 39, "PRODUCT_FEATURE"), (41, 54, "PRODUCT_FEATURE"), (59, 75, "PRODUCT_FEATURE")]}),
    ("The ABC Espresso Machine: 15-bar pressure, frothing wand, and compact stainless steel design.", {"entities": [(4, 24, "PRODUCT_NAME"), (26, 39, "PRODUCT_FEATURE"), (41, 54, "PRODUCT_FEATURE"), (59, 87, "PRODUCT_FEATURE")]}),
    ("ABC High-Performance Laptop: Intel i7 processor, 16GB RAM, and lightning-fast SSD storage.", {"entities": [(0, 28, "PRODUCT_NAME"), (30, 47, "PRODUCT_FEATURE"), (49, 58, "PRODUCT_FEATURE"), (63, 96, "PRODUCT_FEATURE")]}),
    ("Experience the XYZ Smart Home Security System: HD cameras, motion detection, and smartphone integration.", {"entities": [(24, 53, "PRODUCT_NAME"), (55, 65, "PRODUCT_FEATURE"), (67, 83, "PRODUCT_FEATURE"), (88, 114, "PRODUCT_FEATURE")]}),
    ("The ABC Luxury Watch Collection: Swiss-made, automatic movement, and genuine leather strap.", {"entities": [(4, 30, "PRODUCT_NAME"), (32, 41, "PRODUCT_FEATURE"), (43, 60, "PRODUCT_FEATURE"), (65, 82, "PRODUCT_FEATURE")]}),
    ("XYZ Electric Standing Desk: Adjustable height, built-in USB ports, and memory presets.", {"entities": [(0, 25, "PRODUCT_NAME"), (27, 43, "PRODUCT_FEATURE"), (45, 64, "PRODUCT_FEATURE"), (69, 83, "PRODUCT_FEATURE")]}),
    ("Upgrade your kitchen with the ABC Stainless Steel Cookware Set: Non-stick coating and heat-resistant handles.", {"entities": [(33, 62, "PRODUCT_NAME"), (64, 77, "PRODUCT_FEATURE"), (82, 105, "PRODUCT_FEATURE")]}),
    ("Introducing the XYZ Virtual Assistant Speaker: Voice control, smart home integration, and 360-degree sound.", {"entities": [(16, 48, "PRODUCT_NAME"), (50, 62, "PRODUCT_FEATURE"), (64, 85, "PRODUCT_FEATURE"), (90, 104, "PRODUCT_FEATURE")]}),
    ("XYZ Ultra-Light Backpack: Water-resistant, multiple compartments, and ergonomic design.", {"entities": [(0, 22, "PRODUCT_NAME"), (24, 36, "PRODUCT_FEATURE"), (38, 59, "PRODUCT_FEATURE"), (64, 79, "PRODUCT_FEATURE")]}),
    ("Upgrade your gaming setup with the ABC Gaming Monitor: 144Hz refresh rate and AMD FreeSync technology.", {"entities": [(35, 52, "PRODUCT_NAME"), (54, 68, "PRODUCT_FEATURE"), (73, 97, "PRODUCT_FEATURE")]}),
    ("The XYZ Air Purifier: HEPA filtration, smart sensors, and low noise operation.", {"entities": [(4, 21, "PRODUCT_NAME"), (23, 37, "PRODUCT_FEATURE"), (39, 50, "PRODUCT_FEATURE"), (55, 75, "PRODUCT_FEATURE")]}),
    ("ABC Professional Chef's Knife: High-carbon stainless steel, razor-sharp edge, and balanced handle.", {"entities": [(4, 30, "PRODUCT_NAME"), (32, 54, "PRODUCT_FEATURE"), (59, 71, "PRODUCT_FEATURE"), (76, 91, "PRODUCT_FEATURE")]}),
    ("Introducing the XYZ Eco-Friendly Water Bottle: BPA-free, leak-proof, and recyclable materials.", {"entities": [(16, 47, "PRODUCT_NAME"), (49, 58, "PRODUCT_FEATURE"), (63, 73, "PRODUCT_FEATURE"), (78, 95, "PRODUCT_FEATURE")]}),
    ("The ABC Noise-Canceling Headphones: Over-ear design, 20 hours of battery life, and foldable design.", {"entities": [(4, 31, "PRODUCT_NAME"), (33, 47, "PRODUCT_FEATURE"), (52, 75, "PRODUCT_FEATURE"), (80, 95, "PRODUCT_FEATURE")]}),
        ("XYZ Ultra-Light Backpack: Water-resistant, multiple compartments, and ergonomic design. $89.99", {"entities": [(0, 22, "PRODUCT_NAME"), (24, 36, "PRODUCT_FEATURE"), (38, 59, "PRODUCT_FEATURE"), (64, 79, "PRODUCT_FEATURE"), (80, 86, "PRICE")]}),
    ("Upgrade your gaming setup with the ABC Gaming Monitor: 144Hz refresh rate and AMD FreeSync technology. Price: $349.99", {"entities": [(35, 52, "PRODUCT_NAME"), (54, 68, "PRODUCT_FEATURE"), (73, 97, "PRODUCT_FEATURE"), (98, 106, "PRICE")]}),
    ("The XYZ Air Purifier: HEPA filtration, smart sensors, and low noise operation. $149.95", {"entities": [(4, 21, "PRODUCT_NAME"), (23, 37, "PRODUCT_FEATURE"), (39, 50, "PRODUCT_FEATURE"), (55, 75, "PRODUCT_FEATURE"), (76, 83, "PRICE")]}),
    ("ABC Professional Chef's Knife: High-carbon stainless steel, razor-sharp edge, and balanced handle. Price: $79.99", {"entities": [(4, 30, "PRODUCT_NAME"), (32, 54, "PRODUCT_FEATURE"), (59, 71, "PRODUCT_FEATURE"), (76, 91, "PRODUCT_FEATURE"), (92, 100, "PRICE")]}),
    ("Introducing the XYZ Eco-Friendly Water Bottle: BPA-free, leak-proof, and recyclable materials. $14.99", {"entities": [(16, 47, "PRODUCT_NAME"), (49, 58, "PRODUCT_FEATURE"), (63, 73, "PRODUCT_FEATURE"), (78, 95, "PRODUCT_FEATURE"), (96, 103, "PRICE")]}),
    ("The ABC Noise-Canceling Headphones: Over-ear design, 20 hours of battery life, and foldable design. $129.99", {"entities": [(4, 31, "PRODUCT_NAME"), (33, 47, "PRODUCT_FEATURE"), (52, 75, "PRODUCT_FEATURE"), (80, 95, "PRODUCT_FEATURE"), (96, 104, "PRICE")]}),
    ("XYZ Smart TV: 65-inch display, 4K resolution, and built-in streaming apps. Price: $899.00", {"entities": [(0, 14, "BRAND_LOGO"), (15, 23, "PRODUCT_NAME"), (25, 38, "PRODUCT_FEATURE"), (40, 52, "PRODUCT_FEATURE"), (57, 80, "PRODUCT_FEATURE"), (81, 89, "PRICE")]}),
    ("ABC DSLR Camera Kit: 24MP sensor, 4K video recording, and included lens accessories. $1,199.99", {"entities": [(4, 28, "BRAND_LOGO"), (29, 47, "PRODUCT_NAME"), (49, 58, "PRODUCT_FEATURE"), (60, 80, "PRODUCT_FEATURE"), (81, 90, "PRODUCT_FEATURE"), (91, 100, "PRICE")]}),
    ("XYZ Home Office Desk: Spacious work surface, ergonomic design, and cable management system. $249.95", {"entities": [(0, 3, "BRAND_LOGO"), (4, 20, "PRODUCT_NAME"), (22, 38, "PRODUCT_FEATURE"), (40, 56, "PRODUCT_FEATURE"), (61, 86, "PRODUCT_FEATURE"), (87, 95, "PRICE")]}),
    ("XYZ Ultra-Light Backpack: Water-resistant, multiple compartments, and ergonomic design. $89.99. Manufactured on 2023-05-15. Logo: [Logo_Image_URL]", {"entities": [(0, 22, "PRODUCT_NAME"), (24, 36, "PRODUCT_FEATURE"), (38, 59, "PRODUCT_FEATURE"), (64, 79, "PRODUCT_FEATURE"), (80, 86, "PRICE"), (98, 112, "MANUFACTURE_DATE"), (116, 134, "BRAND_LOGO")]}),
    ("Upgrade your gaming setup with the ABC Gaming Monitor: 144Hz refresh rate and AMD FreeSync technology. Price: $349.99. Manufactured on 2023-03-28. Logo: [Logo_Image_URL]", {"entities": [(35, 52, "PRODUCT_NAME"), (54, 68, "PRODUCT_FEATURE"), (73, 97, "PRODUCT_FEATURE"), (98, 106, "PRICE"), (118, 132, "MANUFACTURE_DATE"), (136, 154, "BRAND_LOGO")]}),
    ("The XYZ Air Purifier: HEPA filtration, smart sensors, and low noise operation. $149.95. Manufactured on 2023-01-10. Logo: [Logo_Image_URL]", {"entities": [(4, 21, "PRODUCT_NAME"), (23, 37, "PRODUCT_FEATURE"), (39, 50, "PRODUCT_FEATURE"), (55, 75, "PRODUCT_FEATURE"), (76, 83, "PRICE"), (95, 108, "MANUFACTURE_DATE"), (112, 130, "BRAND_LOGO")]}),
    ("ABC Professional Chef's Knife: High-carbon stainless steel, razor-sharp edge, and balanced handle. Price: $79.99. Manufactured on 2023-02-18. Logo: [Logo_Image_URL]", {"entities": [(4, 30, "PRODUCT_NAME"), (32, 54, "PRODUCT_FEATURE"), (59, 71, "PRODUCT_FEATURE"), (76, 91, "PRODUCT_FEATURE"), (92, 100, "PRICE"), (112, 125, "MANUFACTURE_DATE"), (129, 147, "BRAND_LOGO")]}),
    ("Introducing the XYZ Eco-Friendly Water Bottle: BPA-free, leak-proof, and recyclable materials. $14.99. Manufactured on 2023-04-05. Logo: [Logo_Image_URL]", {"entities": [(16, 47, "PRODUCT_NAME"), (49, 58, "PRODUCT_FEATURE"), (63, 73, "PRODUCT_FEATURE"), (78, 95, "PRODUCT_FEATURE"), (96, 103, "PRICE"), (115, 128, "MANUFACTURE_DATE"), (132, 150, "BRAND_LOGO")]}),
    ("The ABC Noise-Canceling Headphones: Over-ear design, 20 hours of battery life, and foldable design. $129.99. Manufactured on 2023-06-22. Logo: [Logo_Image_URL]", {"entities": [(4, 31, "PRODUCT_NAME"), (33, 47, "PRODUCT_FEATURE"), (52, 75, "PRODUCT_FEATURE"), (80, 95, "PRODUCT_FEATURE"), (96, 104, "PRICE"), (116, 129, "MANUFACTURE_DATE"), (133, 151, "BRAND_LOGO")]}),
    ("XYZ Smart TV: 65-inch display, 4K resolution, and built-in streaming apps. Price: $899.00. Manufactured on 2023-07-10. Logo: [Logo_Image_URL]", {"entities": [(0, 14, "BRAND_LOGO"), (15, 23, "PRODUCT_NAME"), (25, 38, "PRODUCT_FEATURE"), (40, 52, "PRODUCT_FEATURE"), (57, 80, "PRODUCT_FEATURE"), (81, 89, "PRICE"), (101, 118, "MANUFACTURE_DATE"), (122, 140, "BRAND_LOGO")]}),
    ("ABC DSLR Camera Kit: 24MP sensor, 4K video recording, and included lens accessories. $1,199.99. Manufactured on 2023-08-15. Logo: [Logo_Image_URL]", {"entities": [(4, 28, "BRAND_LOGO"), (29, 47, "PRODUCT_NAME"), (49, 58, "PRODUCT_FEATURE"), (60, 80, "PRODUCT_FEATURE"), (81, 90, "PRODUCT_FEATURE"), (91, 100, "PRICE"), (112, 125, "MANUFACTURE_DATE"), (129, 147, "BRAND_LOGO")]}),
    ("XYZ Home Office Desk: Spacious work surface, ergonomic design, and cable management system. $249.95. Manufactured on 2023-09-05. Logo: [Logo_Image_URL]", {"entities": [(0, 3, "BRAND_LOGO"), (4, 20, "PRODUCT_NAME"), (22, 38, "PRODUCT_FEATURE"), (40, 56, "PRODUCT_FEATURE"), (61, 86, "PRODUCT_FEATURE"), (87, 95, "PRICE"), (107, 124, "MANUFACTURE_DATE"), (128, 146, "BRAND_LOGO")]}),
    ("XYZ Ultra-Light Backpack: Water-resistant, multiple compartments, and ergonomic design. ₹5,999. Manufactured on 2023-05-15. Logo: [Logo_Image_URL]", {"entities": [(0, 22, "PRODUCT_NAME"), (24, 36, "PRODUCT_FEATURE"), (38, 59, "PRODUCT_FEATURE"), (64, 79, "PRODUCT_FEATURE"), (80, 90, "PRICE_INR"), (102, 116, "MANUFACTURE_DATE"), (120, 138, "BRAND_LOGO")]}),
    ("Upgrade your gaming setup with the ABC Gaming Monitor: 144Hz refresh rate and AMD FreeSync technology. Price: ₹24,999. Manufactured on 2023-03-28. Logo: [Logo_Image_URL]", {"entities": [(35, 52, "PRODUCT_NAME"), (54, 68, "PRODUCT_FEATURE"), (73, 97, "PRODUCT_FEATURE"), (98, 110, "PRICE_INR"), (122, 136, "MANUFACTURE_DATE"), (140, 158, "BRAND_LOGO")]}),
    ("The XYZ Air Purifier: HEPA filtration, smart sensors, and low noise operation. ₹9,999. Manufactured on 2023-01-10. Logo: [Logo_Image_URL]", {"entities": [(4, 21, "PRODUCT_NAME"), (23, 37, "PRODUCT_FEATURE"), (39, 50, "PRODUCT_FEATURE"), (55, 75, "PRODUCT_FEATURE"), (76, 86, "PRICE_INR"), (98, 111, "MANUFACTURE_DATE"), (115, 133, "BRAND_LOGO")]}),
    ("ABC Professional Chef's Knife: High-carbon stainless steel, razor-sharp edge, and balanced handle. Price: ₹4,499. Manufactured on 2023-02-18. Logo: [Logo_Image_URL]", {"entities": [(4, 30, "PRODUCT_NAME"), (32, 54, "PRODUCT_FEATURE"), (59, 71, "PRODUCT_FEATURE"), (76, 91, "PRODUCT_FEATURE"), (92, 104, "PRICE_INR"), (116, 129, "MANUFACTURE_DATE"), (133, 151, "BRAND_LOGO")]}),
    ("Introducing the XYZ Eco-Friendly Water Bottle: BPA-free, leak-proof, and recyclable materials. ₹799. Manufactured on 2023-04-05. Logo: [Logo_Image_URL]", {"entities": [(16, 47, "PRODUCT_NAME"), (49, 58, "PRODUCT_FEATURE"), (63, 73, "PRODUCT_FEATURE"), (78, 95, "PRODUCT_FEATURE"), (96, 106, "PRICE_INR"), (118, 132, "MANUFACTURE_DATE"), (136, 154, "BRAND_LOGO")]}),
    ("The ABC Noise-Canceling Headphones: Over-ear design, 20 hours of battery life, and foldable design. ₹10,999. Manufactured on 2023-06-22. Logo: [Logo_Image_URL]", {"entities": [(4, 31, "PRODUCT_NAME"), (33, 47, "PRODUCT_FEATURE"), (52, 75, "PRODUCT_FEATURE"), (80, 95, "PRODUCT_FEATURE"), (96, 107, "PRICE_INR"), (119, 132, "MANUFACTURE_DATE"), (136, 154, "BRAND_LOGO")]}),
    ("XYZ Smart TV: 65-inch display, 4K resolution, and built-in streaming apps. Price: ₹64,999. Manufactured on 2023-07-10. Logo: [Logo_Image_URL]", {"entities": [(0, 14, "BRAND_LOGO"), (15, 23, "PRODUCT_NAME"), (25, 38, "PRODUCT_FEATURE"), (40, 52, "PRODUCT_FEATURE"), (57, 80, "PRODUCT_FEATURE"), (81, 93, "PRICE_INR"), (105, 122, "MANUFACTURE_DATE"), (126, 144, "BRAND_LOGO")]}),
    ("ABC DSLR Camera Kit: 24MP sensor, 4K video recording, and included lens accessories. ₹79,999. Manufactured on 2023-08-15. Logo: [Logo_Image_URL]", {"entities": [(4, 28, "BRAND_LOGO"), (29, 47, "PRODUCT_NAME"), (49, 58, "PRODUCT_FEATURE"), (60, 80, "PRODUCT_FEATURE"), (81, 90, "PRODUCT_FEATURE"), (91, 103, "PRICE_INR"), (115, 128, "MANUFACTURE_DATE"), (132, 150, "BRAND_LOGO")]}),
    ("XYZ Home Office Desk: Spacious work surface, ergonomic design, and cable management system. ₹15,499. Manufactured on 2023-09-05. Logo: [Logo_Image_URL]", {"entities": [(0, 3, "BRAND_LOGO"), (4, 20, "PRODUCT_NAME"), (22, 38, "PRODUCT_FEATURE"), (40, 56, "PRODUCT_FEATURE"), (61, 86, "PRODUCT_FEATURE"), (87, 97, "PRICE_INR"), (109, 126, "MANUFACTURE_DATE"), (130, 148, "BRAND_LOGO")]}),
     ("XYZ Ultra-Light Backpack: Water-resistant, multiple compartments, and ergonomic design. $89.99. Manufactured on 2023-05-15. Logo: [Logo_Image_URL]. Complies with environmental standards and cruelty-free materials.", {"entities": [(0, 22, "PRODUCT_NAME"), (24, 36, "PRODUCT_FEATURE"), (38, 59, "PRODUCT_FEATURE"), (64, 79, "PRODUCT_FEATURE"), (80, 86, "PRICE"), (98, 112, "MANUFACTURE_DATE"), (116, 134, "BRAND_LOGO"), (143, 192, "COMPLIANCE"), (196, 239, "DESCRIPTION")]}),
    ("Upgrade your gaming setup with the ABC Gaming Monitor: 144Hz refresh rate and AMD FreeSync technology. Price: $349.99. Manufactured on 2023-03-28. Logo: [Logo_Image_URL]. Complies with energy efficiency regulations. Premium gaming experience with vivid colors.", {"entities": [(35, 52, "PRODUCT_NAME"), (54, 68, "PRODUCT_FEATURE"), (73, 97, "PRODUCT_FEATURE"), (98, 106, "PRICE"), (118, 132, "MANUFACTURE_DATE"), (136, 154, "BRAND_LOGO"), (163, 210, "COMPLIANCE"), (214, 259, "DESCRIPTION")]}),
    ("The XYZ Air Purifier: HEPA filtration, smart sensors, and low noise operation. $149.95. Manufactured on 2023-01-10. Logo: [Logo_Image_URL]. Complies with indoor air quality standards. Creates a healthy living environment.", {"entities": [(4, 21, "PRODUCT_NAME"), (23, 37, "PRODUCT_FEATURE"), (39, 50, "PRODUCT_FEATURE"), (55, 75, "PRODUCT_FEATURE"), (76, 83, "PRICE"), (95, 108, "MANUFACTURE_DATE"), (112, 130, "BRAND_LOGO"), (139, 186, "COMPLIANCE"), (190, 238, "DESCRIPTION")]}),
    ("ABC Professional Chef's Knife: High-carbon stainless steel, razor-sharp edge, and balanced handle. Price: $79.99. Manufactured on 2023-02-18. Logo: [Logo_Image_URL]. Complies with food safety regulations. Perfect for professional chefs and home cooks.", {"entities": [(4, 30, "PRODUCT_NAME"), (32, 54, "PRODUCT_FEATURE"), (59, 71, "PRODUCT_FEATURE"), (76, 91, "PRODUCT_FEATURE"), (92, 100, "PRICE"), (112, 125, "MANUFACTURE_DATE"), (129, 147, "BRAND_LOGO"), (156, 205, "COMPLIANCE"), (209, 261, "DESCRIPTION")]}),
    ("Introducing the XYZ Eco-Friendly Water Bottle: BPA-free, leak-proof, and recyclable materials. $14.99. Manufactured on 2023-04-05. Logo: [Logo_Image_URL]. Complies with eco-friendly standards. Sustainable choice for hydration.", {"entities": [(16, 47, "PRODUCT_NAME"), (49, 58, "PRODUCT_FEATURE"), (63, 73, "PRODUCT_FEATURE"), (78, 95, "PRODUCT_FEATURE"), (96, 103, "PRICE"), (115, 128, "MANUFACTURE_DATE"), (132, 150, "BRAND_LOGO"), (159, 209, "COMPLIANCE"), (213, 270, "DESCRIPTION")]}),
    ("The ABC Noise-Canceling Headphones: Over-ear design, 20 hours of battery life, and foldable design. $129.99. Manufactured on 2023-06-22. Logo: [Logo_Image_URL]. Complies with noise control regulations. Immerse yourself in superior audio quality.", {"entities": [(4, 31, "PRODUCT_NAME"), (33, 47, "PRODUCT_FEATURE"), (52, 75, "PRODUCT_FEATURE"), (80, 95, "PRODUCT_FEATURE"), (96, 104, "PRICE"), (116, 129, "MANUFACTURE_DATE"), (133, 151, "BRAND_LOGO"), (160, 216, "COMPLIANCE"), (220, 274, "DESCRIPTION")]}),
    ("XYZ Smart TV: 65-inch display, 4K resolution, and built-in streaming apps. Price: $899.00. Manufactured on 2023-07-10. Logo: [Logo_Image_URL]. Complies with energy efficiency standards. Enjoy stunning visuals and smart features.", {"entities": [(0, 14, "BRAND_LOGO"), (15, 23, "PRODUCT_NAME"), (25, 38, "PRODUCT_FEATURE"), (40, 52, "PRODUCT_FEATURE"), (57, 80, "PRODUCT_FEATURE"), (81, 89, "PRICE"), (101, 118, "MANUFACTURE_DATE"), (122, 140, "BRAND_LOGO"), (149, 203, "COMPLIANCE"), (207, 265, "DESCRIPTION")]}),
    ("ABC DSLR Camera Kit: 24MP sensor, 4K video recording, and included lens accessories. $1,199.99. Manufactured on 2023-08-15. Logo: [Logo_Image_URL]. Complies with imaging quality standards. Capture breathtaking moments with professional-grade photography.", {"entities": [(4, 28, "BRAND_LOGO"), (29, 47, "PRODUCT_NAME"), (49, 58, "PRODUCT_FEATURE"), (60, 80, "PRODUCT_FEATURE"), (81, 90, "PRODUCT_FEATURE"), (91, 100, "PRICE"), (112, 125, "MANUFACTURE_DATE"), (129, 147, "BRAND_LOGO"), (156, 224, "COMPLIANCE"), (228, 296, "DESCRIPTION")]}),
    ("XYZ Home Office Desk: Spacious work surface, ergonomic design, and cable management system. $249.95. Manufactured on 2023-09-05. Logo: [Logo_Image_URL]. Complies with ergonomic standards. Create an efficient and comfortable workspace.", {"entities": [(0, 3, "BRAND_LOGO"), (4, 20, "PRODUCT_NAME"), (22, 38, "PRODUCT_FEATURE"), (40, 56, "PRODUCT_FEATURE"), (61, 86, "PRODUCT_FEATURE"), (87, 95, "PRICE"), (107, 124, "MANUFACTURE_DATE"), (128, 146, "BRAND_LOGO"), (155, 213, "COMPLIANCE"), (217, 289, "DESCRIPTION")]}),
    # Add more annotated examples...

    



]

# Train the custom NER model
for epoch in range(10):
    random.shuffle(train_data)  # Use the shuffle function from the random module
    for text, annotations in train_data:
        example = Example.from_dict(nlp.make_doc(text), annotations)
        nlp.update([example], drop=0.5, losses={})
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 5.4 MB/s eta 0:00:0000:0100:01
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# /Users/sambitpradhan/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "XYZ Ultra-Light Backpack: Water-resistant, multipl..." with entities "[(0, 22, 'PRODUCT_NAME'), (24, 36, 'PRODUCT_FEATUR...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# ...

# %%
# Example text for testing
another_test_text = "The new iPhone 13 comes with a powerful A15 Bionic chip, stunning camera improvements, and 5G capability."

# Process the test text using the trained model
doc = nlp(another_test_text)

# Print the entities predicted by the model
for ent in doc.ents:
    print(f"Entity: {ent.text}, Label: {ent.label_}")
# Out:
# Entity: A15 Bionic chip, Label: PRODUCT_NAME
# Entity: , and 5G, Label: PRODUCT_FEATURE
